# %% [markdown]
# # Problem Statement::

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ## DATA::

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ## Solution

# %%
import pandas as pd

# %%
path = '/home/ashish/projects/LineaerRegression2_autosale_TVads/regr.xlsx'
data_frame = pd.read_excel(path)
data_frame
# Out:
#    TV Ads  car Sold
# 0       1        14
# 1       3        24
# 2       2        18
# 3       1        17
# 4       3        27

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  ##Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics

# %% [markdown]
# # NORMAL PLOTTING ----> (USNG MATPLOTLIB LIBRARY)

# %%
data_frame.plot('TV Ads','car Sold',style='o')
plt.xlim(-1,5)
plt.ylim(10,30)
plt.ylabel('------CARS SOLD-----')
plt.title('SALES IN SEVERAL UK REGION')
plt.show()

# %% [markdown]
# # REGRESSION PLOTTING ------>(USING SEABORN AND MATLPLOTLIB)

# %%
## regplot() method draw a scatterplot of two variables, x and y, and 
## then fit the regression model y ~ x and plot the resulting regression line 
## and a 95% confidence interval for that regression.

x = data_frame['TV Ads']
y = data_frame['car Sold']
plt.xlim(-1,5)
plt.ylim(10,30)
sns.regplot(x=x,y=y,fit_reg=True)  ## regression plotting
plt.scatter(np.mean(x),np.mean(y),color="red")
plt.show()

# %%
import statsmodels.api as s
import statsmodels.regression.linear_model as sm

# %%
## statsmodels.regression.linear_model.OLS
t = s.add_constant(x)
model = sm.OLS(y,x).fit()
model.summary()
# Out:
# /home/ashish/anaconda3/lib/python3.8/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               car Sold   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     21.43
# Date:                Wed, 29 Dec 2021   Prob (F-statistic):             0.0190
# Time:                        01:16:56   Log-Likelihood:                -9.6687
# No. Observations:                   5   AIC:                             23.34
# Df Residuals:                       3   BIC:                             22.56
# Df Model:                           1
# ...

# %% [markdown]
#         Regression Equation ==> 10 + 5*(TV ads)
# ## R-squared = 87.7% ==> so this regression relationship is very strong.And, 87.7% of variability in the No. of cars sold in several UK regions can be explained by the Linear relationship between Number of TV ads and Number of cars sold.
